# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahzull/dataset-datamining/blob/main/Preprocessing_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("pima_Missing_values.csv")

# %%
df
# Out:
#     NoOfPregency PlasmaGlucoseCon BloodPressure SkinFoldThickness Insuline  \
# 0             10              108            66            <null>        0
# 1              7              107            74                 0        0
# 2              0              179            90                27   <null>
# 3             10              125            70                26   <null>
# 4             10           <null>        <null>                 0        0
# ..           ...              ...           ...               ...      ...
# 685            2           <null>            78                50      140
# 686            1              107            68                19        0
# 687            2               98            60                17      120
# 688            4              122            68                 0        0
# 689            4              145            82                18        0
#
#         BMI DiabetesPedigree Age            Class
# ...

# %%
df.head(10)
# Out:
#   NoOfPregency PlasmaGlucoseCon BloodPressure SkinFoldThickness Insuline  \
# 0           10              108            66            <null>        0
# 1            7              107            74                 0        0
# 2            0              179            90                27   <null>
# 3           10              125            70                26   <null>
# 4           10           <null>        <null>                 0        0
# 5            5              162           104            <null>        0
# 6            7           <null>            50                33      392
# 7            0              131            88                 0        0
# 8            3              132            80                 0   <null>
# 9            7               97            76            <null>       91
#
#       BMI DiabetesPedigree Age            Class
# 0    32.4            0.272  42  tested_positive
# 1    29.6            0.254  31  tested_positive
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   NoOfPregency       690 non-null    object
#  1   PlasmaGlucoseCon   690 non-null    object
#  2   BloodPressure      690 non-null    object
#  3   SkinFoldThickness  690 non-null    object
#  4   Insuline           690 non-null    object
#  5   BMI                690 non-null    object
#  6   DiabetesPedigree   690 non-null    object
#  7   Age                690 non-null    object
#  8   Class              690 non-null    object
# dtypes: object(9)
# memory usage: 48.6+ KB

# %%
df.isnull().sum()
# Out:
# NoOfPregency         0
# PlasmaGlucoseCon     0
# BloodPressure        0
# SkinFoldThickness    0
# Insuline             0
# BMI                  0
# DiabetesPedigree     0
# Age                  0
# Class                0
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# tested_negative    450
# tested_positive    240
# Name: Class, dtype: int64

# %%
df['BMI'].value_counts()
# Out:
# <null>    66
# 31.6      11
# 32        11
# 30.8       9
# 31.2       9
#           ..
# 19.5       1
# 49.7       1
# 43.4       1
# 50         1
# 28.1       1
# Name: BMI, Length: 230, dtype: int64

# %%
na = df.groupby(['NoOfPregency', 'Age', 'Class'])

# %%
na.first()
# Out:
#                                     PlasmaGlucoseCon BloodPressure  \
# NoOfPregency Age    Class
# 0            21     tested_negative              101            64
#                     tested_positive              151            90
#              22     tested_negative              101            65
#                     tested_positive              188            82
#              23     tested_negative               84            82
# ...                                              ...           ...
# <null>       55     tested_negative              103            72
#              65     tested_negative              161            50
#              66     tested_negative              114            88
#              <null> tested_negative           <null>        <null>
#                     tested_positive              115            72
#
#                                     SkinFoldThickness Insuline     BMI  \
# NoOfPregency Age    Class
# ...
