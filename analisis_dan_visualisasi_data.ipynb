# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahzull/dataset-datamining/blob/main/analisis_dan_visualisasi_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("options_KR.csv")

# %%
df
# Out:
#             Date  VKOSPI  KOSPI200  Open_interest  For_KOSPI_Netbuying_Amount  \
# 0     2009-06-02   33.45    180.90        4377777                4.940000e+11
# 1     2009-06-03   32.66    180.47        4562690               -8.997074e+10
# 2     2009-06-04   32.56    180.31        4827524               -1.090000e+11
# 3     2009-06-05   32.95    175.75        5022921                9.842024e+10
# 4     2009-06-08   30.41    177.77        5293996                4.329179e+10
# ...          ...     ...       ...            ...                         ...
# 2575  2019-11-01   13.22    275.82        2942228                1.390000e+11
# 2576  2019-11-04   13.32    278.43        2984183                7.023820e+10
# 2577  2019-11-05   13.42    282.54        3024099                3.250000e+11
# 2578  2019-11-06   13.89    284.38        3081381                2.380000e+11
# 2579  2019-11-07   13.78    284.52        3175919               -1.550000e+11
#
# ...

# %%
df.head(10)
# Out:
#          Date  VKOSPI  KOSPI200  Open_interest  For_KOSPI_Netbuying_Amount  \
# 0  2009-06-02   33.45    180.90        4377777                4.940000e+11
# 1  2009-06-03   32.66    180.47        4562690               -8.997074e+10
# 2  2009-06-04   32.56    180.31        4827524               -1.090000e+11
# 3  2009-06-05   32.95    175.75        5022921                9.842024e+10
# 4  2009-06-08   30.41    177.77        5293996                4.329179e+10
# 5  2009-06-09   30.46    177.67        5520545                9.251058e+10
# 6  2009-06-10   29.31    174.91        5993901                4.340000e+11
# 7  2009-06-11   30.01    180.91        6296014                7.060000e+11
# 8  2009-06-12   29.78    181.43        1006401                2.490000e+11
# 9  2009-06-15   31.29    182.69        1440250               -4.750943e+10
#
#    For_Future_Netbuying_Quantity  For_Call_Netbuying_Quantity  \
# 0                          -4953                       -24646
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date                             2580 non-null   object
#  1   VKOSPI                           2580 non-null   float64
#  2   KOSPI200                         2580 non-null   float64
#  3   Open_interest                    2580 non-null   int64
#  4   For_KOSPI_Netbuying_Amount       2580 non-null   float64
#  5   For_Future_Netbuying_Quantity    2580 non-null   int64
#  6   For_Call_Netbuying_Quantity      2580 non-null   int64
#  7   For_Put_Netbuying_Quantity       2580 non-null   int64
#  8   Indiv_Future_Netbuying_Quantity  2580 non-null   int64
#  9   Indiv_Call_Netbuying_Quantity    2580 non-null   int64
#  10  Indiv_Put_Netbuying_Quantity     2580 non-null   int64
#  11  PCRatio                          2580 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Date                               0
# VKOSPI                             0
# KOSPI200                           0
# Open_interest                      0
# For_KOSPI_Netbuying_Amount         0
# For_Future_Netbuying_Quantity      0
# For_Call_Netbuying_Quantity        0
# For_Put_Netbuying_Quantity         0
# Indiv_Future_Netbuying_Quantity    0
# Indiv_Call_Netbuying_Quantity      0
# Indiv_Put_Netbuying_Quantity       0
# PCRatio                            0
# Day_till_expiration                0
# Day_of_a_week                      0
# dtype: int64

# %%
df['Day_of_a_week'].value_counts()
# Out:
# Thu    520
# Tue    519
# Fri    514
# Mon    514
# Wed    513
# Name: Day_of_a_week, dtype: int64

# %%
df['PCRatio'].value_counts()
# Out:
# 1.00    79
# 0.92    78
# 0.94    76
# 0.96    71
# 0.85    70
#         ..
# 0.39     1
# 0.33     1
# 0.40     1
# 0.41     1
# 0.38     1
# Name: PCRatio, Length: 117, dtype: int64

# %%
na = df.groupby(['Date', 'VKOSPI','Day_of_a_week'])

# %%
na.first()
# Out:
#                                  KOSPI200  Open_interest  \
# Date       VKOSPI Day_of_a_week
# 2009-06-02 33.45  Tue              180.90        4377777
# 2009-06-03 32.66  Wed              180.47        4562690
# 2009-06-04 32.56  Thu              180.31        4827524
# 2009-06-05 32.95  Fri              175.75        5022921
# 2009-06-08 30.41  Mon              177.77        5293996
# ...                                   ...            ...
# 2019-11-01 13.22  Fri              275.82        2942228
# 2019-11-04 13.32  Mon              278.43        2984183
# 2019-11-05 13.42  Tue              282.54        3024099
# 2019-11-06 13.89  Wed              284.38        3081381
# 2019-11-07 13.78  Thu              284.52        3175919
#
#                                  For_KOSPI_Netbuying_Amount  \
# Date       VKOSPI Day_of_a_week
# 2009-06-02 33.45  Tue                          4.940000e+11
# 2009-06-03 32.66  Wed                         -8.997074e+10
# ...

# %%
df['Indiv_Call_Netbuying_Quantity'].value_counts()
# Out:
#  8949     3
# -1992     3
# -466      2
# -402      2
# -5003     2
#          ..
#  14977    1
#  2077     1
# -567      1
#  2680     1
#  25430    1
# Name: Indiv_Call_Netbuying_Quantity, Length: 2525, dtype: int64

# %%
total = df['PCRatio'].sum()

# %%
total
# Out:
# 2463.48

# %%
df['Day_till_expiration'].sum()
# Out:
# 25756

# %%
sns.boxplot(x="Day_of_a_week", y="Day_till_expiration", data=df)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date                             2580 non-null   object
#  1   VKOSPI                           2580 non-null   float64
#  2   KOSPI200                         2580 non-null   float64
#  3   Open_interest                    2580 non-null   int64
#  4   For_KOSPI_Netbuying_Amount       2580 non-null   float64
#  5   For_Future_Netbuying_Quantity    2580 non-null   int64
#  6   For_Call_Netbuying_Quantity      2580 non-null   int64
#  7   For_Put_Netbuying_Quantity       2580 non-null   int64
#  8   Indiv_Future_Netbuying_Quantity  2580 non-null   int64
#  9   Indiv_Call_Netbuying_Quantity    2580 non-null   int64
#  10  Indiv_Put_Netbuying_Quantity     2580 non-null   int64
#  11  PCRatio                          2580 non-null   float64
# ...

# %%
df.plot(kind="scatter", x="Day_till_expiration", y="For_Put_Netbuying_Quantity")
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Day_till_expiration', ylabel='For_Put_Netbuying_Quantity'>

# %%
sns.FacetGrid(df, hue="Day_of_a_week", height=5) \
   .map(plt.scatter, "For_Put_Netbuying_Quantity", "PCRatio") \
   .add_legend()
plt.show()

# %%
g = df.groupby(['Day_of_a_week', 'For_Put_Netbuying_Quantity', 'PCRatio'])
g.first()
# Out:
#                                                         Date  VKOSPI  \
# Day_of_a_week For_Put_Netbuying_Quantity PCRatio
# Fri           -152337                    0.98     2010-11-05   19.61
#               -104158                    1.14     2010-02-05   22.71
#               -79356                     1.26     2010-05-07   26.45
#               -78978                     0.44     2011-08-05   28.31
#               -76968                     1.24     2011-02-18   17.76
# ...                                                      ...     ...
# Wed            78836                     0.82     2010-02-03   20.51
#                79373                     0.87     2019-09-11   13.50
#                86890                     0.84     2009-06-10   29.31
#                94202                     0.78     2009-12-02   20.38
#                111068                    1.24     2010-06-09   23.57
#
#                                                   KOSPI200  Open_interest  \
# ...
